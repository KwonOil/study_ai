# %%
#import
import pandas as pd
import numpy as np
import os

# %%
os.listdir('./')
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '0417.ipynb',
#  '0418.ipynb',
#  '0421.ipynb',
#  '0422.ipynb',
#  'data',
#  'DataFrame_ex.ipynb',
#  'Op_ex.ipynb',
#  'part2_read.ipynb',
#  'requirements.txt',
#  'Series_ex.ipynb']

# %%
# csv 파일 불러오기
sample = pd.read_csv('./data/read_csv_sample.csv')
sample

df_file = './data/read_csv_sample.csv'
df_sample = pd.read_csv(df_file)
df_sample

file_path = os.path.join('data','read_csv_sample.csv')
print(file_path)
df_sample2 = pd.read_csv(file_path)
df_sample2
# Out:
# data\read_csv_sample.csv
#    c0  c1  c2  c3
# 0   0   1   4   7
# 1   1   2   5   8
# 2   2   3   6   9

# %%
sample = pd.read_csv('./data/read_csv_sample.csv', header = 0,index_col = 'c0')
# header = 0행의 인자들을 열이름으로 쓰기
# index_col = 'c0'열이 행 인덱스가 된다 
sample
# Out:
#     c1  c2  c3
# c0
# 0    1   4   7
# 1    2   5   8
# 2    3   6   9

# %%
# excel 파일 불러오기
ex1 = pd.read_excel('./data/남북한발전전력량.xlsx')
ex1

# 문자변수 저장하고 변수 이용 불러오기
ex_path = './data/df_excelwriter.xlsx'
ex2 = pd.read_excel(ex_path)
ex2

# os.path.join()함수 이용해서 불러오기
ex_path2 = os.path.join('data','df_excelwriter.xlsx')
ex3 = pd.read_excel(ex_path2)
ex3
# Out:
#     name algol basic c++
# 0  Jerry     A     C  B+
# 1   Riah    A+     B   C
# 2   Paul     B    B+  C+

# %%
ex1 = pd.read_excel('./data/남북한발전전력량.xlsx', index_col = '1990')
ex1
# Out:
#      전력량 (억㎾h) 발전 전력별  1991  1992  1993  1994  1995  1996  1997  1998  ...  \
# 1990                                                                   ...
# 1077        남한     합계  1186  1310  1444  1650  1847  2055  2244  2153  ...
# 64         NaN     수력    51    49    60    41    55    52    54    61  ...
# 484        NaN     화력   573   696   803  1022  1122  1264  1420  1195  ...
# 529        NaN    원자력   563   565   581   587   670   739   771   897  ...
# -          NaN    신재생     -     -     -     -     -     -     -     -  ...
# 277         북한     합계   263   247   221   231   230   213   193   170  ...
# 156        NaN     수력   150   142   133   138   142   125   107   102  ...
# 121        NaN     화력   113   105    88    93    88    88    86    68  ...
# -          NaN    원자력     -     -     -     -     -     -     -     -  ...
#
#       2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 1990
# 1077  4031  4224  4336  4747  4969  5096  5171  5220  5281  5404
# ...

# %%
sam_json = pd.read_json('./data/sample.json')
sam_json
# Out:
#             year developer opensource
# pandas      2008       홍길동       True
# Numpy       2006       이순신       True
# matplotlib  2003       김수미       True

# %%
sample2 = pd.DataFrame({
    "name" : ['홍길동','이순신'],
    "age" : [10, 20]
})
sample2 = sample2.set_index('name')
print(sample2)

sample2.to_csv('./data/user_name_age.csv')
sample3 = pd.read_csv('./data/user_name_age.csv', encoding = 'utf-8') # encoding = 'cp949'
print(sample3)
# Out:
#       age
# name
# 홍길동    10
# 이순신    20
#   name  age
# 0  홍길동   10
# 1  이순신   20

# %%
sample4 = pd.read_csv('./data/user_name_age.csv',encoding = 'utf-8', usecols = ['age'])
print(sample4)
# Out:
#    age
# 0   10
# 1   20

# %%
sample4 = pd.read_csv('./data/user_name_age.csv', encoding = 'utf-8', index_col = 'age')
print(sample4)
# Out:
#     name
# age
# 10   홍길동
# 20   이순신

# %%
sample5 = pd.DataFrame({
    "name" : ['홍길동','이순신','이명수','차무건'],
    "age" : [10, 20, 30,40]
})
sample5.to_csv('./data/user_name_age2.csv')

csv2 = pd.read_csv('./data/user_name_age2.csv', encoding = 'utf-8', na_values = ['NA','-','None'])
csv2
# Out:
#    Unnamed: 0 name  age
# 0           0  홍길동   10
# 1           1  이순신   20
# 2           2  이명수   30
# 3           3  차무건   40

# %%
csv2 = pd.read_csv('./data/user_name_age2.csv', encoding = 'utf-8', dtype = {'name' : str, 'age' : int})
csv2
# Out:
#    Unnamed: 0 name  age
# 0           0  홍길동   10
# 1           1  이순신   20
# 2           2  이명수   30
# 3           3  차무건   40

# %% [markdown]
# # 문제1) ./data/read_csv_sample.csv
#
# 데이터프레임의 상위 5개 행을 출력하시오.

# %%
ex1 = pd.read_csv('./data/read_csv_sample.csv')
ex1.head()
# Out:
#    c0  c1  c2  c3
# 0   0   1   4   7
# 1   1   2   5   8
# 2   2   3   6   9

# %% [markdown]
# # 문제2) 인코딩 처리
#
# data/sales_kor.csv 파일은 한글이 포함되어 있어 cp949 또는 utf-8-sig 인코딩이 필요합니다.
#
# 올바른 인코딩을 지정하여 데이터를 읽고, head()로 5개 행을 출력하시오.

# %%
ex2 = pd.read_csv('./data/남북한발전전력량2.csv', encoding = 'cp949')
ex2.head()
# Out:
#   전력량 (억㎾h) 발전 전력별   1990   1991   1992   1993   1994   1995   1996   1997  \
# 0        남한     합계  1,077  1,186  1,310  1,444  1,650  1,847  2,055  2,244
# 1       NaN     수력     64     51     49     60     41     55     52     54
# 2       NaN     화력    484    573    696    803  1,022  1,122  1,264  1,420
# 3       NaN    원자력    529    563    565    581    587    670    739    771
# 4       NaN    신재생      -      -      -      -      -      -      -      -
#
#    ...   2007   2008   2009   2010   2011   2012   2013   2014   2015   2016
# 0  ...  4,031  4,224  4,336  4,747  4,969  5,096  5,171  5,220  5,281  5,404
# 1  ...     50     56     56     65     78     77     84     78     58     66
# 2  ...  2,551  2,658  2,802  3,196  3,343  3,430  3,581  3,427  3,402  3,523
# 3  ...  1,429  1,510  1,478  1,486  1,547  1,503  1,388  1,564  1,648  1,620
# 4  ...      -      -      -      -      -     86    118    151    173    195
#
# [5 rows x 29 columns]

# %%
ex3 = pd.read_excel('./data/남북한발전전력량.xlsx')
ex3
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
ex4 = pd.read_excel('./data/남북한발전전력량.xlsx', sheet_name = "데이터", header = 1)
# xls = pd.ExcelFile('./data/남북한발전전력량.xlsx')
# print(xls.sheet_names)
ex4
# Out:
#     남한   합계 1077 1186 1310 1444  1650  1847  2055  2244  ...  4031  4224  \
# 0  NaN   수력   64   51   49   60    41    55    52    54  ...    50    56
# 1  NaN   화력  484  573  696  803  1022  1122  1264  1420  ...  2551  2658
# 2  NaN  원자력  529  563  565  581   587   670   739   771  ...  1429  1510
# 3  NaN  신재생    -    -    -    -     -     -     -     -  ...     -     -
# 4   북한   합계  277  263  247  221   231   230   213   193  ...   236   255
# 5  NaN   수력  156  150  142  133   138   142   125   107  ...   133   141
# 6  NaN   화력  121  113  105   88    93    88    88    86  ...   103   114
# 7  NaN  원자력    -    -    -    -     -     -     -     -  ...     -     -
#
#    4336  4747  4969  5096  5171  5220  5281  5404
# 0    56    65    78    77    84    78    58    66
# 1  2802  3196  3343  3430  3581  3427  3402  3523
# 2  1478  1486  1547  1503  1388  1564  1648  1620
# 3     -     -     -    86   118   151   173   195
# 4   235   237   211   215   221   216   190   239
# ...

# %%
ex5 = pd.read_excel('./data/남북한발전전력량.xlsx', sheet_name = "데이터", index_col = 0)
ex5
# Out:
#           발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  1998  ...  \
# 전력량 (억㎾h)                                                               ...
# 남한            합계  1077  1186  1310  1444  1650  1847  2055  2244  2153  ...
# NaN           수력    64    51    49    60    41    55    52    54    61  ...
# NaN           화력   484   573   696   803  1022  1122  1264  1420  1195  ...
# NaN          원자력   529   563   565   581   587   670   739   771   897  ...
# NaN          신재생     -     -     -     -     -     -     -     -     -  ...
# 북한            합계   277   263   247   221   231   230   213   193   170  ...
# NaN           수력   156   150   142   133   138   142   125   107   102  ...
# NaN           화력   121   113   105    88    93    88    88    86    68  ...
# NaN          원자력     -     -     -     -     -     -     -     -     -  ...
#
#            2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 전력량 (억㎾h)
# ...

# %%
ex6 = pd.read_excel('./data/남북한발전전력량.xlsx', sheet_name = "데이터", usecols = 'B:C')
ex6
# Out:
#   발전 전력별  1990
# 0     합계  1077
# 1     수력    64
# 2     화력   484
# 3    원자력   529
# 4    신재생     -
# 5     합계   277
# 6     수력   156
# 7     화력   121
# 8    원자력     -

# %%
ex7 = pd.read_excel('./data/남북한발전전력량.xlsx',
                    sheet_name = "데이터",
                    skiprows = 2
                   )
ex7
# Out:
#   Unnamed: 0   수력   64   51   49   60    41    55    52    54  ...    50  \
# 0        NaN   화력  484  573  696  803  1022  1122  1264  1420  ...  2551
# 1        NaN  원자력  529  563  565  581   587   670   739   771  ...  1429
# 2        NaN  신재생    -    -    -    -     -     -     -     -  ...     -
# 3         북한   합계  277  263  247  221   231   230   213   193  ...   236
# 4        NaN   수력  156  150  142  133   138   142   125   107  ...   133
# 5        NaN   화력  121  113  105   88    93    88    88    86  ...   103
# 6        NaN  원자력    -    -    -    -     -     -     -     -  ...     -
#
#    56.1  56.2    65    78    77    84  78.1    58    66
# 0  2658  2802  3196  3343  3430  3581  3427  3402  3523
# 1  1510  1478  1486  1547  1503  1388  1564  1648  1620
# 2     -     -     -     -    86   118   151   173   195
# 3   255   235   237   211   215   221   216   190   239
# 4   141   125   134   132   135   139   130   100   128
# ...

# %%
ex8 = pd.read_excel('./data/남북한발전전력량.xlsx',
                    sheet_name = "데이터",
                    nrows = 5,
                    na_values = ['-','N/A']
                   )
ex8
# Out:
#   전력량 (억㎾h) 발전 전력별    1990    1991    1992    1993    1994    1995    1996  \
# 0        남한     합계  1077.0  1186.0  1310.0  1444.0  1650.0  1847.0  2055.0
# 1       NaN     수력    64.0    51.0    49.0    60.0    41.0    55.0    52.0
# 2       NaN     화력   484.0   573.0   696.0   803.0  1022.0  1122.0  1264.0
# 3       NaN    원자력   529.0   563.0   565.0   581.0   587.0   670.0   739.0
# 4       NaN    신재생     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      1997  ...    2007    2008    2009    2010    2011  2012  2013  2014  \
# 0  2244.0  ...  4031.0  4224.0  4336.0  4747.0  4969.0  5096  5171  5220
# 1    54.0  ...    50.0    56.0    56.0    65.0    78.0    77    84    78
# 2  1420.0  ...  2551.0  2658.0  2802.0  3196.0  3343.0  3430  3581  3427
# 3   771.0  ...  1429.0  1510.0  1478.0  1486.0  1547.0  1503  1388  1564
# 4     NaN  ...     NaN     NaN     NaN     NaN     NaN    86   118   151
#
#    2015  2016
# 0  5281  5404
# 1    58    66
# 2  3402  3523
# ...

# %%
ex9 = pd.read_excel('./data/남북한발전전력량.xlsx',
                    sheet_name = "데이터",
                    engine='openpyxl'
                   )
ex9
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
df = pd.read_json('./data/user_1.json')
df
# Out:
#     이름  나이
# 0  이순신  25
# 1  홍길동  30

# %%
df2 = pd.read_json('./data/user_1.json', orient = 'records')
df2
# Out:
#     이름  나이
# 0  이순신  25
# 1  홍길동  30

# %%
df3 = pd.read_json('./data/user_1.json', typ = 'series')
df3
# Out:
# 이름    [이순신, 홍길동]
# 나이      [25, 30]
# dtype: object

# %%
df4 = pd.read_json('./data/user_1.json', lines = True)
df4
# Out:
#            이름        나이
# 0  [이순신, 홍길동]  [25, 30]

# %%
# p103 <table>로 만들어진 html 파일만 가능
url = './data/sample.html'
tables = pd.read_html(url)

# print(len(tables))
for i in range(len(tables)):
    print("tables[%s]"%i)
    print(tables[i])
    print()
# Out:
# tables[0]
#    Unnamed: 0  c0  c1  c2  c3
# 0           0   0   1   4   7
# 1           1   1   2   5   8
# 2           2   2   3   6   9
#
# tables[1]
#          name  year        developer  opensource
# 0       NumPy  2006  Travis Oliphant        True
# 1  matplotlib  2003   John D. Hunter        True
# 2      pandas  2008    Wes Mckinneye        True

# %%
df = tables[1]
df = df.set_index(['name'])
df
# Out:
#             year        developer  opensource
# name
# NumPy       2006  Travis Oliphant        True
# matplotlib  2003   John D. Hunter        True
# pandas      2008    Wes Mckinneye        True
